# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_celeste@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio de Python: Clases y Objetos con Canciones
#
# ## Ejercicio 1. Definición de la clase Cancion
# 1.1. Define  la clase Cancion, la cual va a tener 4 atributos básicos. (título,  artista, album, genero y duración)
#
# 1.2. Crea un método para la clase Cancion que nos muestre la información de la canción.
#
# 1.3. Crea un método que nos permita comparar la duración de dos canciones y nos indique cuál de las dos es más larga.
#
# 1.4. Crea un método que nos permita calcular la popularidad de una canción en función de varios criterios.
#
# - La puntuación base debe ser de 50.
#
# - Las canciones de entre 2 y 4 minutos de duración son más populares, por lo que suman 20 puntos. Las demás restan 10.
#
# - Las canciones de los géneros pop, rock, hip-hop y electrónicas son populares, por lo que suman 20 puntos. El resto de géneros restan 5 puntos.
#
# - Si una canción pertenece a un álbum suma 10 puntos.
#
# 1.5. Crea dos instancias de la clase canción con la siguiente info: ("Stairway to Heaven", "Led Zeppelin", "Led Zeppelin IV", 8.02, "Rock") y ("What's Going On", "Marvin Gaye", "What's Going On", 3.53, "Soul")
#
# 1.6. Comprueba el funcionamiento de cada uno de los métodos de la clase

# %%
##1.1
class Cancion:
    def __init__(self, titulo, artista, album, genero, duracion):
        self.titulo = titulo
        self.artista  = artista
        self.album = album
        self.genero = genero
        self.duracion = duracion
##1.2.
    def mostrar_info(self):
       return f"titulo: {self.titulo}\nartista: {self.artista}\nalbum: {self.album}\ngenero: {self.genero}\nduracion: {self.duracion}"
##1.3. 
    def duracion_en_segundos(self):
        #creamos para pasar a segundos los minutos en una cancion
        try:
            minutos, fraccion = map(float, self.duracion.split("."))
            segundos = int(fraccion * 60)
            return int(minutos * 60 + segundos)
        except ValueError:
            raise ValueError("Formato de duración incorrecto. Debe ser minutos.decimales.")
    
    def comparar_duracion (self, otra):
        duracion_self = self.duracion_en_segundos()
        duracion_otra = otra.duracion_en_segundos()

        if duracion_self < duracion_otra: 
            print(f"la cancion {self.titulo} es mas corta que {otra.titulo}")
        elif duracion_self > duracion_otra: 
            print(f"la cancion {self.titulo} es mas larga que {otra.titulo}")
        else:
            print("las canciones comparadas duran lo mismo")
##1.4 
    def calculo_popularidad(self):

        #base
        popularidad = 50 

        #segun duracion de la cancion
        duracion_self = self.duracion_en_segundos()
        if 120 <= duracion_self <= 240:
            popularidad += 20
        else:
            popularidad -=10

        #tipo de genero
        mejores_generos = ["pop", "rock", "hip-hop", "electronica"]
        if self.genero.lower() in mejores_generos:
            popularidad +=20
        else:
            popularidad -=5
        
        # pertenencia a un album
        if self.album: 
            popularidad += 10

        return popularidad


    ##1.5
cancion1 = Cancion("Stairway to Heaven", "Led Zeppelin", "Led Zeppelin IV", "Rock", "8.02" )
cancion2 = Cancion("What's Going On", "Marvin Gaye", "What's Going On", "Soul","3.53")

    ##1.6
print(cancion1.mostrar_info())
print("____")
print(cancion2.mostrar_info())
print("____")
print(cancion1.comparar_duracion(cancion2))
print("____")
print(f"\nla popularidad de '{cancion1.titulo}' es: {cancion1.calculo_popularidad()} puntos.")
print(f"\nla popularidad de '{cancion2.titulo}' es: {cancion2.calculo_popularidad()} puntos.")
# Out:
# titulo: Stairway to Heaven
# artista: Led Zeppelin
# album: Led Zeppelin IV
# genero: Rock
# duracion: 8.02
# ____
# titulo: What's Going On
# artista: Marvin Gaye
# album: What's Going On
# genero: Soul
# duracion: 3.53
# ____
# la cancion Stairway to Heaven es mas corta que What's Going On
# None
# ____
#
# la popularidad de 'Stairway to Heaven' es: 70 puntos.
#
# la popularidad de 'What's Going On' es: 45 puntos.

# %% [markdown]
# ## Ejercicio 2. Definición de la subclase Colaboracion
# 2.1. Define  la subclase Colaboracion, la cual va a tener 5 atributos heredados de la clase Cancion (titulo, artista, album, duracion y genero) y va a tener un atributo básico (artistas_colaboradores)
#
#
# 2.2. Crea un método que nos permita mostrar todos los detalles de una canción concreta (incluidos los artistas colaboradores).
#
# 2.3. Crea un método que nos permita comprobar si una canción es o no una colaboración
#
# 2.4. Crea un método que nos permita obtener el número de colaboradores.
#
# 2.5. Crea un método que nos actualice la puntuación de la canción, ya qu es una colaboración sumará 5 puntos por cada colaborador
#
# 2.6. Crea un método que nos permita obtener el colaborador principal asumiendo que es el primer colaborador en la lista.
#
# 2.7. Crea una instancias de la clase Colaboracion con la siguiente info: ("Meant to Be", "Bebe Rexha", "Expectations", 2.44, "Country Pop", ["Florida Georgia Line"])
#
# 2.8. Comprueba el funcionamiento de cada uno de los métodos de la subclase

# %%
##2.1
class Colaboracion(Cancion):
    def __init__ (self,titulo, artista, album, genero, duracion,artistas_colaboradores):
        super().__init__(titulo, artista, album,genero,duracion)
        self.artistas_colaboradores = artistas_colaboradores

##2.2
    def mostrar_info(self):
        info_base = super().mostrar_info()
        info_colaboradores = f"Artistas colaboradores: {', '.join(self.artistas_colaboradores)}" if self.artistas_colaboradores else "Artistas colaboradores: Ninguno"
        return f"{info_base}\n{info_colaboradores}"

##2.3
    def es_colaboracion(self):
        return bool(self.artistas_colaboradores)

##2.4
    def cantidad_colaboradores(self):
        return len(self.artistas_colaboradores) 
    
#2.5
    def actualizar_puntuacion(self):
        popularidad_base = self.calculo_popularidad()
        # Suma puntos por cada colaborador
        puntos_extra = len(self.artistas_colaboradores) * 5
        popularidad_final = popularidad_base + puntos_extra
        return popularidad_final

##2.6
    def colaborador_principal(self):
        # Verifica si hay colaboradores y devuelve el primero; de lo contrario, indica que no hay
        if self.artistas_colaboradores:
            return self.artistas_colaboradores[0]
        return "No hay colaboradores"
##2.7
cancion_meant_to_be = Colaboracion(
    titulo="Meant to Be",
    artista="Bebe Rexha",
    album="Expectations",
    genero="Country Pop",
    duracion="2.44",
    artistas_colaboradores=["Florida Georgia Line"])


##2.8 comprobacion de metodos

# 1. Mostrar información completa (incluye colaboradores)
print("meetodo mostrar_info():")
print(cancion_meant_to_be.mostrar_info())
print()

# 2. Obtener la cantidad de colaboradores
print(f"\nnumero de colaboradores: {cancion_meant_to_be.cantidad_colaboradores()}")
print()

# 3. Comprobar si es colaboración
print("\n metodo es_colaboracion():")
print(f"es colaboracion? {cancion_meant_to_be.es_colaboracion()}")
print()

# 4. Actualizar la puntuación de la canción
nueva_puntuacion = cancion_meant_to_be.actualizar_puntuacion()
print("\nmetodo actualizar_puntuacion():")
print(f"puntuacion actualizada: {nueva_puntuacion}")

# 5. Obtener el colaborador principal
print("\nmetodo colaborador_principal():")
print(f"colaborador principal: {cancion_meant_to_be.colaborador_principal()}")
# Out:
# meetodo mostrar_info():
# titulo: Meant to Be
# artista: Bebe Rexha
# album: Expectations
# genero: Country Pop
# duracion: 2.44
# Artistas colaboradores: Florida Georgia Line
#
#
# numero de colaboradores: 1
#
#
#  metodo es_colaboracion():
# es colaboracion? True
#
#
# metodo actualizar_puntuacion():
# puntuacion actualizada: 50
#
# metodo colaborador_principal():
# colaborador principal: Florida Georgia Line

# %% [markdown]
# ## Ejercicio 3. Definición de la subclase CancionPremiada
# 3.1. Define  la clase CancionPremiada, la cual va a tener 5 atributos heredados de la clase Cancion (titulo, artista, album, duracion y genero) y va a tener un atributo básico (premios)
#
# 3.2. Crea un método para la subclase CancionPremiada que nos permita mostrar todos los detalles de una canción concreta (incluidos los premios ganados).
#
# 3.3. Crea un método que nos permita obtener el número de premios que ha ganado la canción.
#
# 3.4. Crea un método que nos permita conocer si la canción ha ganado algún premio prestigioso de una lista predefinida de premios prestigiosos.
# ```python
# lista_premios = ["Grammy", "Oscar", "Golden Globe", "Brit Award"]
#
# ```
#
# 3.5. Crea una instancias de la clase CancionPremiada con la siguiente info: ("Just the Way You Are", "Bruno Mars", "Doo-Wops & Hooligans", 3.40, "Pop", ["Grammy", "American Music Award"])
#
# 3.6. Comprueba el funcionamiento de cada uno de los métodos de la subclase

# %%
##3.1
class CancionPremiada(Cancion):
    def __init__ (self,titulo, artista, album,genero,duracion,premios):
        super().__init__(titulo, artista, album,genero,duracion)
        self.premios = premios

#3.2
    def mostrar_info(self):
        info_base = super().mostrar_info()
        info_premios = f"premios: {', '.join(self.premios)}" if self.premios else "Sin premios logrados"
        return f"{info_base}\n{info_premios}"
    
#3.3
    def cantidad_premios(self):
        return len(self.premios)

#3.4
    def premio_obtenido(self):
        lista_premios = ["Grammy", "Oscar", "Golden Globe", "Brit Award"]
        premios_prestigiosos = [premio for premio in self.premios if premio in lista_premios]
        if premios_prestigiosos:
            print(f"\nLa canción ha ganado los siguientes premios prestigiosos: {', '.join(premios_prestigiosos)}")
        else:
            print("\nNo ha ganado premios prestigiosos.")
#3.5
cancion_Just_the_way_u_r = CancionPremiada(
    titulo= "Just the Way You Are",
    artista="Bruno Mars",
    album="Doo-Wops & Hooligans",
    genero="Pop",
    duracion="3.40",
    premios=["Grammy", "American Music Award"])

#3.6
print(cancion_Just_the_way_u_r.mostrar_info())
print(f"\nCantidad de premios: {cancion_Just_the_way_u_r.cantidad_premios()}")
cancion_Just_the_way_u_r.premio_obtenido()
# Out:
# titulo: Just the Way You Are
# artista: Bruno Mars
# album: Doo-Wops & Hooligans
# genero: Pop
# duracion: 3.40
# premios: Grammy, American Music Award
#
# Cantidad de premios: 2
#
# La canción ha ganado los siguientes premios prestigiosos: Grammy

# %% [markdown]
# ## Ejercicio 4. Definición de la clase Playlist
# 4.1. Define  la clase Playlist, la cual va a tener 1 atributo básico. (nombre) y va a tener una lista con las canciones (inicialmente estará vacía)
#
# 4.2. Crea un método para la clase Playlist que nos permita añadir una canción a nuestra Playlist. (Esta canción va a ser un objeto de la clase Cancion)
#
# 4.3. Crea un método que nos permita eliminar canciones de nuestra Playlist.
#
# 4.4. Crea un método que nos permita visualizar el nombre de nuestra playlist, las canciones que tiene y su información.
#
# 4.5. Crea un método que nos permita encontrar y visualizar todas las caciones de un artista concreto de nuestra Playlist
#
# 4.6. Crea un método para contar el número total de canciones de nuestra playlist y su duración total
#
# 4.7. Crea un método que nos permita ordenar aleatoriamente las canciones de nuestra playlist
#
# 4.8. Crea una instancia de la clase Playlist
#
# 4.9. Dadas las listas canciones, canciones_colaboracion y canciones_premiadas crea instancias de cada clase que le corresponda y añade las canciones a la clase Playlist
#
# 4.10. Elimina las siguientes canciones. ["God Only Knows", "All of Me", "FRIENDS"]
#
# 4.11. Comprueba el funcionamiento de cada uno de los métodos de la clase

# %%
canciones = [
    ("Yesterday", "The Beatles", "Help!", 2.05, "Rock"),
    ("Bohemian Rhapsody", "Queen", "A Night at the Opera", 5.55, "Rock"),
    ("Hotel California", "Eagles", "Hotel California", 6.30, "Rock"),
    ("Like a Rolling Stone", "Bob Dylan", "Highway 61 Revisited", 6.13, "Folk Rock"),
    ("What's Going On", "Marvin Gaye", "What's Going On", 3.53, "Soul"),
    ("Stairway to Heaven", "Led Zeppelin", "Led Zeppelin IV", 8.02, "Rock"),
    ("Imagine", "John Lennon", "Imagine", 3.01, "Pop Rock"),
    ("Smells Like Teen Spirit", "Nirvana", "Nevermind", 5.01, "Grunge"),
    ("Good Vibrations", "The Beach Boys", "Smiley Smile", 3.37, "Pop"),
    ("Purple Haze", "Jimi Hendrix", "Are You Experienced", 2.51, "Rock"),
    ("Billie Jean", "Michael Jackson", "Thriller", 4.54, "Pop"),
    ("I Can't Get No (Satisfaction)", "The Rolling Stones", "Out of Our Heads", 3.43, "Rock"),
    ("God Only Knows", "The Beach Boys", "Pet Sounds", 2.55, "Pop"),
    ("A Day in the Life", "The Beatles", "Sgt. Pepper's Lonely Hearts Club Band", 5.38, "Rock"),
    ("Layla", "Derek and the Dominos", "Layla and Other Assorted Love Songs", 7.05, "Rock"),
    ("What's Love Got to Do with It", "Tina Turner", "Private Dancer", 3.49, "Pop"),
    ("Thunder Road", "Bruce Springsteen", "Born to Run", 4.49, "Rock"),
    ("Hotel California", "Eagles", "Hotel California", 6.30, "Rock"),
    ("Superstition", "Stevie Wonder", "Talking Book", 4.26, "Funk"),
    ("Waterloo Sunset", "The Kinks", "Something Else by The Kinks", 3.15, "Rock"),
    ("Gimme Shelter", "The Rolling Stones", "Let It Bleed", 4.31, "Rock"),
    ("What'd I Say", "Ray Charles", "What'd I Say", 5.04, "R&B"),
    ("Heroes", "David Bowie", "'Heroes'", 6.11, "Rock"),
    ("California Dreamin'", "The Mamas & the Papas", "If You Can Believe Your Eyes and Ears", 2.42, "Pop"),
    ("Losing My Religion", "R.E.M.", "Out of Time", 4.28, "Alternative Rock"),
    ("House of the Rising Sun", "The Animals", "The Animals", 4.29, "Rock"),
    ("Sweet Child o' Mine", "Guns N' Roses", "Appetite for Destruction", 5.56, "Rock"),
    ("All Along the Watchtower", "The Jimi Hendrix Experience", "Electric Ladyland", 4.01, "Rock"),
    ("Jolene", "Dolly Parton", "Jolene", 2.42, "Country"),
    ("I Want to Hold Your Hand", "The Beatles", "Meet the Beatles!", 2.24, "Pop"),
    ("Born to Run", "Bruce Springsteen", "Born to Run", 4.30, "Rock"),
    ("No Woman, No Cry", "Bob Marley & The Wailers", "Live!", 7.08, "Reggae"),
    ("Every Breath You Take", "The Police", "Synchronicity", 4.13, "Rock"),
    ("Respect", "Aretha Franklin", "I Never Loved a Man the Way I Love You", 2.29, "Soul"),
    ("Bridge Over Troubled Water", "Simon & Garfunkel", "Bridge Over Troubled Water", 4.52, "Folk"),
    ("Light My Fire", "The Doors", "The Doors", 7.06, "Rock"),
    ("My Girl", "The Temptations", "The Temptations Sing Smokey", 2.55, "Soul"),
    ("Hey Jude", "The Beatles", "Hey Jude", 7.11, "Rock"),
    ("Ring of Fire", "Johnny Cash", "Ring of Fire: The Best of Johnny Cash", 2.38, "Country"),
    ("Walk on the Wild Side", "Lou Reed", "Transformer", 4.12, "Rock"),
    ("I Will Survive", "Gloria Gaynor", "Love Tracks", 4.57, "Disco"),
    ("Ain't No Mountain High Enough", "Marvin Gaye & Tammi Terrell", "United", 2.29, "Soul"),
    ("I Heard It Through the Grapevine", "Marvin Gaye", "In the Groove", 3.13, "Soul"),
    ("Let It Be", "The Beatles", "Let It Be", 4.03, "Rock"),
    ("Hallelujah", "Leonard Cohen", "Various Positions", 4.36, "Folk"),
    ("Blowin' in the Wind", "Bob Dylan", "The Freewheelin' Bob Dylan", 2.49, "Folk"),
    ("Hotel California", "Eagles", "Hotel California", 6.30, "Rock"),
    ("Born to Be Wild", "Steppenwolf", "Steppenwolf", 3.28, "Rock"),
    ("You Shook Me All Night Long", "AC/DC", "Back in Black", 3.30, "Rock"),
    ("Good Times Bad Times", "Led Zeppelin", "Led Zeppelin", 2.47, "Rock")
]

canciones_colaboracion = [
    ("Rain on Me", "Lady Gaga", "Chromatica", 3.02, "Pop", ["Ariana Grande"]),
    ("Señorita", "Shawn Mendes", "Shawn Mendes", 3.10, "Pop", ["Camila Cabello"]),
    ("I Don't Care", "Ed Sheeran", "No.6 Collaborations Project", 3.39, "Pop", ["Justin Bieber"]),
    ("Shallow", "Lady Gaga", "A Star Is Born", 3.37, "Soundtrack", ["Bradley Cooper"]),
    ("Havana", "Camila Cabello", "Camila", 3.37, "Pop", ["Young Thug"]),
    ("Savage Love", "Jawsh 685", "Savage Love", 2.51, "Pop", ["Jason Derulo"]),
    ("One Kiss", "Calvin Harris", "One Kiss", 3.34, "Electronic", ["Dua Lipa"]),
    ("Stay", "The Kid LAROI", "Stay", 2.21, "Pop", ["Justin Bieber"]),
    ("Closer", "The Chainsmokers", "Collage", 4.04, "Electronic", ["Halsey"]),
    ("Rockstar", "DaBaby", "Blame It on Baby", 3.01, "Hip-Hop", ["Roddy Ricch"]),
    ("Sicko Mode", "Travis Scott", "Astroworld", 5.12, "Hip-Hop", ["Drake"]),
    ("Finesse (Remix)", "Bruno Mars", "24K Magic", 3.37, "Funk", ["Cardi B"]),
    ("Eastside", "Benny Blanco", "Friends Keep Secrets", 2.53, "Pop", ["Halsey", "Khalid"]),
    ("Don't Let Me Down", "The Chainsmokers", "Collage", 3.28, "Electronic", ["Daya"]),
    ("Taki Taki", "DJ Snake", "Carte Blanche", 3.32, "Reggaeton", ["Selena Gomez", "Ozuna", "Cardi B"]),
    ("Beautiful People", "Ed Sheeran", "No.6 Collaborations Project", 3.18, "Pop", ["Khalid"]),
    ("I Like It", "Cardi B", "Invasion of Privacy", 4.13, "Hip-Hop", ["Bad Bunny", "J Balvin"]),
    ("Meant to Be", "Bebe Rexha", "Expectations", 2.44, "Country Pop", ["Florida Georgia Line"]),
    ("MIA", "Bad Bunny", "X 100PRE", 3.30, "Reggaeton", ["Drake"]),
    ("FRIENDS", "Marshmello", "Joytime II", 3.22, "Electronic", ["Anne-Marie"]),
    ("No Brainer", "DJ Khaled", "Father of Asahd", 4.20, "Hip-Hop", ["Justin Bieber", "Chance the Rapper", "Quavo"]),
    ("Tusa", "Karol G", "Tusa", 3.20, "Reggaeton", ["Nicki Minaj"]),
    ("Talk", "Khalid", "Free Spirit", 3.17, "R&B", ["Disclosure"]),
    ("Goodbyes", "Post Malone", "Hollywood's Bleeding", 2.55, "Hip-Hop", ["Young Thug"]),
    ("Señorita", "Shawn Mendes", "Romance", 3.10, "Pop", ["Camila Cabello"]),
    ("Señorita", "Shawn Mendes", "Romance", 3.10, "Pop", ["Camila Cabello"]),
    ("Dusk Till Dawn", "Zayn", "Icarus Falls", 4.27, "Pop", ["Sia"]),
    ("Unforgettable", "French Montana", "Jungle Rules", 3.53, "Hip-Hop", ["Swae Lee"]),
    ("Drip Too Hard", "Lil Baby", "Drip Harder", 2.25, "Hip-Hop", ["Gunna"]),
    ("Wake Me Up", "Avicii", "True", 4.07, "Electronic", ["Aloe Blacc"]),
    ("Stargazing", "Travis Scott", "Astroworld", 4.30, "Hip-Hop", ["Kid Cudi"]),
    ("HUMBLE.", "Kendrick Lamar", "DAMN.", 2.57, "Hip-Hop", ["Mike WiLL Made-It"]),
    ("Bodak Yellow", "Cardi B", "Invasion of Privacy", 3.54, "Hip-Hop", ["J White Did It"]),
    ("Love Lies", "Khalid", "Love, Simon", 3.22, "R&B", ["Normani"]),
    ("Body", "Loud Luxury", "Nights Like This", 2.43, "Electronic", ["Brando"]),
    ("I Took a Pill in Ibiza", "Mike Posner", "At Night, Alone", 3.19, "Electronic", ["Seeb"]),
    ("Hotline Bling", "Drake", "Views", 4.27, "Hip-Hop", ["Nineteen85"]),
    ("Falling", "Trevor Daniel", "Nicotine", 2.39, "Pop", ["Charlie Handsome"]),
    ("SAD!", "XXXTENTACION", "?", 2.46, "Hip-Hop", ["John Cunningham"]),
    ("Without Me", "Halsey", "Manic", 3.21, "Pop", ["Louis Bell"]),
    ("Hot Girl Summer", "Megan Thee Stallion", "Hot Girl Summer", 3.19, "Hip-Hop", ["Nicki Minaj", "Ty Dolla $ign"]),
    ("Delicate", "Taylor Swift", "Reputation", 3.52, "Pop", ["Max Martin"]),
    ("Good Old Days", "Macklemore", "Gemini", 4.00, "Pop", ["Kesha"]),
    ("Attention", "Charlie Puth", "Voicenotes", 3.31, "Pop", ["Jacob Kasher"]),
    ("Dancing with a Stranger", "Sam Smith", "Love Goes", 2.51, "Pop", ["Normani"]),
    ("IDGAF", "Dua Lipa", "Dua Lipa", 3.38, "Pop", ["Jason Evigan"]),
    ("Don't Call Me Up", "Mabel", "High Expectations", 2.58, "Pop", ["Steve Mac"]),
    ("Talk Dirty", "Jason Derulo", "Tattoos", 2.57, "Hip-Hop", ["2 Chainz"]),
    ("Let Me Love You", "DJ Snake", "Encore", 3.25, "Electronic", ["Justin Bieber"]),
]

canciones_premiadas = [
    ("Rolling in the Deep", "Adele", "21", 3.48, "Soul", ["Grammy", "Brit Award", "MTV Video Music Award"]),
    ("Bad Guy", "Billie Eilish", "When We All Fall Asleep, Where Do We Go?", 3.14, "Alternative", ["Grammy", "MTV Europe Music Award"]),
    ("Uptown Funk", "Mark Ronson", "Uptown Special", 4.30, "Funk", ["Grammy", "Brit Award"]),
    ("Hello", "Adele", "25", 4.55, "Soul", ["Grammy", "Brit Award", "Billboard Music Award"]),
    ("Stay with Me", "Sam Smith", "In the Lonely Hour", 2.52, "Pop", ["Grammy", "Brit Award", "iHeartRadio Music Award"]),
    ("Thinking Out Loud", "Ed Sheeran", "x", 4.41, "Pop", ["Grammy", "Brit Award", "Ivor Novello Award"]),
    ("Shape of You", "Ed Sheeran", "÷", 3.53, "Pop", ["Grammy", "Brit Award", "Billboard Music Award"]),
    ("We Are Young", "Fun.", "Some Nights", 4.10, "Alternative", ["Grammy", "MTV Video Music Award"]),
    ("Royals", "Lorde", "Pure Heroine", 3.10, "Pop", ["Grammy", "MTV Video Music Award"]),
    ("HUMBLE.", "Kendrick Lamar", "DAMN.", 2.57, "Hip-Hop", ["Grammy", "MTV Video Music Award", "BET Hip Hop Award"]),
    ("Blinding Lights", "The Weeknd", "After Hours", 3.22, "Pop", ["Billboard Music Award", "MTV Video Music Award"]),
    ("I Will Always Love You", "Whitney Houston", "The Bodyguard", 4.31, "Soul", ["Grammy", "American Music Award"]),
    ("My Heart Will Go On", "Celine Dion", "Let's Talk About Love", 4.40, "Pop", ["Grammy", "Golden Globe", "Academy Award"]),
    ("Toxic", "Britney Spears", "In the Zone", 3.19, "Pop", ["Grammy", "MTV Europe Music Award"]),
    ("Rehab", "Amy Winehouse", "Back to Black", 3.35, "Soul", ["Grammy", "Brit Award"]),
    ("Bad Romance", "Lady Gaga", "The Fame Monster", 4.54, "Pop", ["Grammy", "MTV Video Music Award", "Brit Award"]),
    ("Tears in Heaven", "Eric Clapton", "Rush", 4.36, "Rock", ["Grammy", "Brit Award"]),
    ("Kiss from a Rose", "Seal", "Seal", 4.48, "Pop", ["Grammy", "Brit Award"]),
    ("Fallin'", "Alicia Keys", "Songs in A Minor", 3.30, "Soul", ["Grammy", "MTV Video Music Award"]),
    ("Just the Way You Are", "Bruno Mars", "Doo-Wops & Hooligans", 3.40, "Pop", ["Grammy", "American Music Award"]),
    ("All of Me", "John Legend", "Love in the Future", 4.30, "R&B", ["Billboard Music Award", "iHeartRadio Music Award"]),
    ("Formation", "Beyoncé", "Lemonade", 3.26, "R&B", ["Grammy", "MTV Video Music Award", "BET Award"]),
    ("Chandelier", "Sia", "1000 Forms of Fear", 3.36, "Pop", ["MTV Video Music Award", "ARIA Music Award"]),
    ("Happy", "Pharrell Williams", "G I R L", 3.53, "Pop", ["Grammy", "Billboard Music Award"]),
    ("Someone Like You", "Adele", "21", 4.45, "Soul", ["Grammy", "Brit Award"]),
    ("All of Me", "John Legend", "Love in the Future", 4.30, "R&B", ["Billboard Music Award", "iHeartRadio Music Award"]),
    ("Formation", "Beyoncé", "Lemonade", 3.26, "R&B", ["Grammy", "MTV Video Music Award", "BET Award"]),
    ("Chandelier", "Sia", "1000 Forms of Fear", 3.36, "Pop", ["MTV Video Music Award", "ARIA Music Award"]),
    ("Happy", "Pharrell Williams", "G I R L", 3.53, "Pop", ["Grammy", "Billboard Music Award"]),
    ("Someone Like You", "Adele", "21", 4.45, "Soul", ["Grammy", "Brit Award"]),
    ("Rolling in the Deep", "Adele", "21", 3.48, "Soul", ["Grammy", "Brit Award", "MTV Video Music Award"]),
    ("Rehab", "Amy Winehouse", "Back to Black", 3.35, "Soul", ["Grammy", "Brit Award"]),
    ("Rolling in the Deep", "Adele", "21", 3.48, "Soul", ["Grammy", "Brit Award", "MTV Video Music Award"]),
    ("Royals", "Lorde", "Pure Heroine", 3.10, "Pop", ["Grammy", "MTV Video Music Award"]),
    ("Blinding Lights", "The Weeknd", "After Hours", 3.22, "Pop", ["Billboard Music Award", "MTV Video Music Award"]),
    ("I Will Always Love You", "Whitney Houston", "The Bodyguard", 4.31, "Soul", ["Grammy", "American Music Award"]),
    ("My Heart Will Go On", "Celine Dion", "Let's Talk About Love", 4.40, "Pop", ["Grammy", "Golden Globe", "Academy Award"]),
    ("Toxic", "Britney Spears", "In the Zone", 3.19, "Pop", ["Grammy", "MTV Europe Music Award"]),
    ("Rehab", "Amy Winehouse", "Back to Black", 3.35, "Soul", ["Grammy", "Brit Award"]),
    ("Hello", "Adele", "25", 4.55, "Soul", ["Grammy", "Brit Award", "Billboard Music Award"]),
    ("Rolling in the Deep", "Adele", "21", 3.48, "Soul", ["Grammy", "Brit Award", "MTV Video Music Award"]),
    ("Bad Romance", "Lady Gaga", "The Fame Monster", 4.54, "Pop", ["Grammy", "MTV Video Music Award", "Brit Award"]),
    ("We Are Young", "Fun.", "Some Nights", 4.10, "Alternative", ["Grammy", "MTV Video Music Award"]),
    ("Rolling in the Deep", "Adele", "21", 3.48, "Soul", ["Grammy", "Brit Award", "MTV Video Music Award"]),
    ("HUMBLE.", "Kendrick Lamar", "DAMN.", 2.57, "Hip-Hop", ["Grammy", "MTV Video Music Award", "BET Hip Hop Award"]),
    ("Blinding Lights", "The Weeknd", "After Hours", 3.22, "Pop", ["Billboard Music Award", "MTV Video Music Award"]),
    ("All of Me", "John Legend", "Love in the Future", 4.30, "R&B", ["Billboard Music Award", "iHeartRadio Music Award"]),
    ("Formation", "Beyoncé", "Lemonade", 3.26, "R&B", ["Grammy", "MTV Video Music Award", "BET Award"])
]

# %%
class Playlist:
    def __init__(self,nombre):
        self.nombre=nombre
        self.canciones=[]

##4.2 
    def agregar_cancion(self, cancion):
        if isinstance(cancion, Cancion):
            self.canciones.append(cancion)
            print(f"la cancion {cancion.titulo} se agrego a la playlist {self.nombre}")
        else:
            print("Error, la cancion no es valida")
        
    #4.3
    def eliminar_cancion(self, titulo):
        # Buscar la canción por título
        cancion_a_eliminar = next((c for c in self.canciones if c.titulo.lower() == titulo.lower()), None)
        
        if cancion_a_eliminar:
            self.canciones.remove(cancion_a_eliminar)
            print(f"La canción '{titulo}' se eliminó de la playlist '{self.nombre}'.")
        else:
            print(f"La canción '{titulo}' no se encontró en la playlist '{self.nombre}'.")

    #4.4
            
    def mostrar_info_completa(self):
        if self.canciones:
            canciones_info = "\n\n".join([cancion.mostrar_info() for cancion in self.canciones])
            return f"playlist: {self.nombre}\n\ncanciones:\n{canciones_info}"
        else:
            return f"playlist: {self.nombre}\nNo hay canciones en esta playlist."
        
    #4.5
    def buscar_canciones_por_artista(self, artista):
            canciones_artista = [cancion for cancion in self.canciones if cancion.artista.lower() == artista.lower()]
            
            if canciones_artista:
                canciones_str = "\n\n".join([cancion.mostrar_info() for cancion in canciones_artista])
                return f"canciones de {artista} en la playlist '{self.nombre}':\n\n{canciones_str}"
            else:
                return f"No se encontraron canciones de {artista} en la playlist '{self.nombre}'."
            
    #4.6
    def contar_canciones_y_duracion_total(self):
        num_canciones = len(self.canciones)  
        duracion_total_segundos = 0  
        
        for cancion in self.canciones:
            minutos, fraccion_minuto = divmod(float(cancion.duracion), 1)
            segundos = round(fraccion_minuto * 60)
            duracion_total_segundos += int(minutos) * 60 + segundos
        
        # Convertimos la duración total de segundos a minutos y segundos
        minutos_totales = duracion_total_segundos // 60
        segundos_totales = duracion_total_segundos % 60
        
        return num_canciones, minutos_totales, segundos_totales

#4.7
    import random

    def ordenar_aleatoriamente(self):
        if self.canciones:
            random.shuffle(self.canciones)
            print(f"las canciones de la playlist '{self.nombre}' se han ordenado aleatoriamente.")
        else:
            print(f"no hay canciones en la playlist '{self.nombre}' para ordenar.")

#4.8
mi_playlist = Playlist("Mi Playlist Favorita")

#4.9
        # Crear y agregar canciones estándar
for c in canciones:
    cancion = Cancion(*c)  # Usamos la clase Cancion para instanciar
    mi_playlist.agregar_cancion(cancion)

# Crear y agregar canciones de colaboración
for c in canciones_colaboracion:
    cancion_colaborativa = Colaboracion(*c)  # Usamos CancionColaboracion para instanciar
    mi_playlist.agregar_cancion(cancion_colaborativa)

# Crear y agregar canciones premiadas
for c in canciones_premiadas:
    cancion_premiada = CancionPremiada(*c)  # Usamos CancionPremiada para instanciar
    mi_playlist.agregar_cancion(cancion_premiada)

#4.10
    # Canciones a eliminar
cancion_a_eliminar = ["God Only Knows", "All of Me", "FRIENDS"]

    # Eliminar las canciones
for titulo in canciones_a_eliminar:
        mi_playlist.eliminar_cancion(titulo)

#4.11
# Mostrar todas las canciones en la playlist
        print("Canciones en la playlist:")
        mi_playlist.mostrar_info_completa()
# Out:
# la cancion Yesterday se agrego a la playlist Mi Playlist Favorita
# la cancion Bohemian Rhapsody se agrego a la playlist Mi Playlist Favorita
# la cancion Hotel California se agrego a la playlist Mi Playlist Favorita
# la cancion Like a Rolling Stone se agrego a la playlist Mi Playlist Favorita
# la cancion What's Going On se agrego a la playlist Mi Playlist Favorita
# la cancion Stairway to Heaven se agrego a la playlist Mi Playlist Favorita
# la cancion Imagine se agrego a la playlist Mi Playlist Favorita
# la cancion Smells Like Teen Spirit se agrego a la playlist Mi Playlist Favorita
# la cancion Good Vibrations se agrego a la playlist Mi Playlist Favorita
# la cancion Purple Haze se agrego a la playlist Mi Playlist Favorita
# la cancion Billie Jean se agrego a la playlist Mi Playlist Favorita
# la cancion I Can't Get No (Satisfaction) se agrego a la playlist Mi Playlist Favorita
# la cancion God Only Knows se agrego a la playlist Mi Playlist Favorita
# la cancion A Day in the Life se agrego a la playlist Mi Playlist Favorita
# la cancion Layla se agrego a la playlist Mi Playlist Favorita
# la cancion What's Love Got to Do with It se agrego a la playlist Mi Playlist Favorita
# la cancion Thunder Road se agrego a la playlist Mi Playlist Favorita
# la cancion Hotel California se agrego a la playlist Mi Playlist Favorita
# la cancion Superstition se agrego a la playlist Mi Playlist Favorita
# la cancion Waterloo Sunset se agrego a la playlist Mi Playlist Favorita
# la cancion Gimme Shelter se agrego a la playlist Mi Playlist Favorita
# la cancion What'd I Say se agrego a la playlist Mi Playlist Favorita
# la cancion Heroes se agrego a la playlist Mi Playlist Favorita
# la cancion California Dreamin' se agrego a la playlist Mi Playlist Favorita
# la cancion Losing My Religion se agrego a la playlist Mi Playlist Favorita
# la cancion House of the Rising Sun se agrego a la playlist Mi Playlist Favorita
# la cancion Sweet Child o' Mine se agrego a la playlist Mi Playlist Favorita
# la cancion All Along the Watchtower se agrego a la playlist Mi Playlist Favorita
# la cancion Jolene se agrego a la playlist Mi Playlist Favorita
# la cancion I Want to Hold Your Hand se agrego a la playlist Mi Playlist Favorita
# la cancion Born to Run se agrego a la playlist Mi Playlist Favorita
# la cancion No Woman, No Cry se agrego a la playlist Mi Playlist Favorita
# la cancion Every Breath You Take se agrego a la playlist Mi Playlist Favorita
# la cancion Respect se agrego a la playlist Mi Playlist Favorita
# la cancion Bridge Over Troubled Water se agrego a la playlist Mi Playlist Favorita
# la cancion Light My Fire se agrego a la playlist Mi Playlist Favorita
# la cancion My Girl se agrego a la playlist Mi Playlist Favorita
# la cancion Hey Jude se agrego a la playlist Mi Playlist Favorita
# la cancion Ring of Fire se agrego a la playlist Mi Playlist Favorita
# la cancion Walk on the Wild Side se agrego a la playlist Mi Playlist Favorita
# la cancion I Will Survive se agrego a la playlist Mi Playlist Favorita
# la cancion Ain't No Mountain High Enough se agrego a la playlist Mi Playlist Favorita
# la cancion I Heard It Through the Grapevine se agrego a la playlist Mi Playlist Favorita
# la cancion Let It Be se agrego a la playlist Mi Playlist Favorita
# la cancion Hallelujah se agrego a la playlist Mi Playlist Favorita
# la cancion Blowin' in the Wind se agrego a la playlist Mi Playlist Favorita
# la cancion Hotel California se agrego a la playlist Mi Playlist Favorita
# la cancion Born to Be Wild se agrego a la playlist Mi Playlist Favorita
# la cancion You Shook Me All Night Long se agrego a la playlist Mi Playlist Favorita
# la cancion Good Times Bad Times se agrego a la playlist Mi Playlist Favorita
# la cancion Rain on Me se agrego a la playlist Mi Playlist Favorita
# la cancion Señorita se agrego a la playlist Mi Playlist Favorita
# la cancion I Don't Care se agrego a la playlist Mi Playlist Favorita
# la cancion Shallow se agrego a la playlist Mi Playlist Favorita
# la cancion Havana se agrego a la playlist Mi Playlist Favorita
# la cancion Savage Love se agrego a la playlist Mi Playlist Favorita
# la cancion One Kiss se agrego a la playlist Mi Playlist Favorita
# la cancion Stay se agrego a la playlist Mi Playlist Favorita
# la cancion Closer se agrego a la playlist Mi Playlist Favorita
# la cancion Rockstar se agrego a la playlist Mi Playlist Favorita
# la cancion Sicko Mode se agrego a la playlist Mi Playlist Favorita
# la cancion Finesse (Remix) se agrego a la playlist Mi Playlist Favorita
# la cancion Eastside se agrego a la playlist Mi Playlist Favorita
# la cancion Don't Let Me Down se agrego a la playlist Mi Playlist Favorita
# la cancion Taki Taki se agrego a la playlist Mi Playlist Favorita
# la cancion Beautiful People se agrego a la playlist Mi Playlist Favorita
# la cancion I Like It se agrego a la playlist Mi Playlist Favorita
# la cancion Meant to Be se agrego a la playlist Mi Playlist Favorita
# la cancion MIA se agrego a la playlist Mi Playlist Favorita
# la cancion FRIENDS se agrego a la playlist Mi Playlist Favorita
# la cancion No Brainer se agrego a la playlist Mi Playlist Favorita
# la cancion Tusa se agrego a la playlist Mi Playlist Favorita
# la cancion Talk se agrego a la playlist Mi Playlist Favorita
# la cancion Goodbyes se agrego a la playlist Mi Playlist Favorita
# la cancion Señorita se agrego a la playlist Mi Playlist Favorita
# la cancion Señorita se agrego a la playlist Mi Playlist Favorita
# la cancion Dusk Till Dawn se agrego a la playlist Mi Playlist Favorita
# la cancion Unforgettable se agrego a la playlist Mi Playlist Favorita
# la cancion Drip Too Hard se agrego a la playlist Mi Playlist Favorita
# la cancion Wake Me Up se agrego a la playlist Mi Playlist Favorita
# la cancion Stargazing se agrego a la playlist Mi Playlist Favorita
# la cancion HUMBLE. se agrego a la playlist Mi Playlist Favorita
# la cancion Bodak Yellow se agrego a la playlist Mi Playlist Favorita
# la cancion Love Lies se agrego a la playlist Mi Playlist Favorita
# la cancion Body se agrego a la playlist Mi Playlist Favorita
# la cancion I Took a Pill in Ibiza se agrego a la playlist Mi Playlist Favorita
# la cancion Hotline Bling se agrego a la playlist Mi Playlist Favorita
# la cancion Falling se agrego a la playlist Mi Playlist Favorita
# la cancion SAD! se agrego a la playlist Mi Playlist Favorita
# la cancion Without Me se agrego a la playlist Mi Playlist Favorita
# la cancion Hot Girl Summer se agrego a la playlist Mi Playlist Favorita
# la cancion Delicate se agrego a la playlist Mi Playlist Favorita
# la cancion Good Old Days se agrego a la playlist Mi Playlist Favorita
# la cancion Attention se agrego a la playlist Mi Playlist Favorita
# la cancion Dancing with a Stranger se agrego a la playlist Mi Playlist Favorita
# la cancion IDGAF se agrego a la playlist Mi Playlist Favorita
# la cancion Don't Call Me Up se agrego a la playlist Mi Playlist Favorita
# la cancion Talk Dirty se agrego a la playlist Mi Playlist Favorita
# la cancion Let Me Love You se agrego a la playlist Mi Playlist Favorita
# la cancion Rolling in the Deep se agrego a la playlist Mi Playlist Favorita
# la cancion Bad Guy se agrego a la playlist Mi Playlist Favorita
# la cancion Uptown Funk se agrego a la playlist Mi Playlist Favorita
# la cancion Hello se agrego a la playlist Mi Playlist Favorita
# la cancion Stay with Me se agrego a la playlist Mi Playlist Favorita
# la cancion Thinking Out Loud se agrego a la playlist Mi Playlist Favorita
# la cancion Shape of You se agrego a la playlist Mi Playlist Favorita
# la cancion We Are Young se agrego a la playlist Mi Playlist Favorita
# la cancion Royals se agrego a la playlist Mi Playlist Favorita
# la cancion HUMBLE. se agrego a la playlist Mi Playlist Favorita
# la cancion Blinding Lights se agrego a la playlist Mi Playlist Favorita
# la cancion I Will Always Love You se agrego a la playlist Mi Playlist Favorita
# la cancion My Heart Will Go On se agrego a la playlist Mi Playlist Favorita
# la cancion Toxic se agrego a la playlist Mi Playlist Favorita
# la cancion Rehab se agrego a la playlist Mi Playlist Favorita
# la cancion Bad Romance se agrego a la playlist Mi Playlist Favorita
# la cancion Tears in Heaven se agrego a la playlist Mi Playlist Favorita
# la cancion Kiss from a Rose se agrego a la playlist Mi Playlist Favorita
# la cancion Fallin' se agrego a la playlist Mi Playlist Favorita
# la cancion Just the Way You Are se agrego a la playlist Mi Playlist Favorita
# la cancion All of Me se agrego a la playlist Mi Playlist Favorita
# la cancion Formation se agrego a la playlist Mi Playlist Favorita
# la cancion Chandelier se agrego a la playlist Mi Playlist Favorita
# la cancion Happy se agrego a la playlist Mi Playlist Favorita
# la cancion Someone Like You se agrego a la playlist Mi Playlist Favorita
# la cancion All of Me se agrego a la playlist Mi Playlist Favorita
# la cancion Formation se agrego a la playlist Mi Playlist Favorita
# la cancion Chandelier se agrego a la playlist Mi Playlist Favorita
# la cancion Happy se agrego a la playlist Mi Playlist Favorita
# la cancion Someone Like You se agrego a la playlist Mi Playlist Favorita
# la cancion Rolling in the Deep se agrego a la playlist Mi Playlist Favorita
# la cancion Rehab se agrego a la playlist Mi Playlist Favorita
# la cancion Rolling in the Deep se agrego a la playlist Mi Playlist Favorita
# la cancion Royals se agrego a la playlist Mi Playlist Favorita
# la cancion Blinding Lights se agrego a la playlist Mi Playlist Favorita
# la cancion I Will Always Love You se agrego a la playlist Mi Playlist Favorita
# la cancion My Heart Will Go On se agrego a la playlist Mi Playlist Favorita
# la cancion Toxic se agrego a la playlist Mi Playlist Favorita
# la cancion Rehab se agrego a la playlist Mi Playlist Favorita
# la cancion Hello se agrego a la playlist Mi Playlist Favorita
# la cancion Rolling in the Deep se agrego a la playlist Mi Playlist Favorita
# la cancion Bad Romance se agrego a la playlist Mi Playlist Favorita
# la cancion We Are Young se agrego a la playlist Mi Playlist Favorita
# la cancion Rolling in the Deep se agrego a la playlist Mi Playlist Favorita
# la cancion HUMBLE. se agrego a la playlist Mi Playlist Favorita
# la cancion Blinding Lights se agrego a la playlist Mi Playlist Favorita
# la cancion All of Me se agrego a la playlist Mi Playlist Favorita
# la cancion Formation se agrego a la playlist Mi Playlist Favorita
# La canción 'God Only Knows' se eliminó de la playlist 'Mi Playlist Favorita'.
# Canciones en la playlist:
# La canción 'All of Me' se eliminó de la playlist 'Mi Playlist Favorita'.
# Canciones en la playlist:
# La canción 'FRIENDS' se eliminó de la playlist 'Mi Playlist Favorita'.
# Canciones en la playlist:
